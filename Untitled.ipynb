# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc

# %%
timeage = pd.read_csv("TimeAge.csv")
region = pd.read_csv("Region.csv")
time = pd.read_csv("Time.csv")
weather = pd.read_csv("Weather.csv")
searchtrend = pd.read_csv("SearchTrend.csv")
timeprovince = pd.read_csv("TimeProvince.csv")
timegender = pd.read_csv("TimeGender.csv")
patientinfo = pd.read_csv("PatientInfo.csv")
patientroute = pd.read_csv("PatientRoute.csv")
cases = pd.read_csv("Case.csv")
world = pd.read_csv('covid_19_clean_complete.csv')
world2 = pd.read_csv('COVID19_open_line_list.csv')

# %%
world2 = world2[['country','ID']].groupby('country').count().reset_index()
world2
# Out:
#                  country     ID
# 0            Afghanistan      1
# 1                Algeria      1
# 2              Australia     15
# 3                Austria      2
# 4                Bahrain     20
# 5                Belgium      1
# 6                 Brazil      1
# 7               Cambodia      1
# 8                 Canada     10
# 9                  China  10446
# 10               Croatia      3
# 11               Ecuador      1
# 12                 Egypt      1
# 13               Estonia      1
# 14               Finland      2
# 15                France     19
# 16               Georgia      2
# 17               Germany     20
# 18                Greece      1
# 19                 India      3
# 20                  Iran     28
# 21                  Iraq      6
# 22                Israel      4
# 23                 Italy    588
# 24                 Japan    731
# 25                Kuwait     26
# 26               Lebanon      3
# 27             Lithuania      1
# ...

# %%
world = world[['Lat','Country/Region','Confirmed']].groupby('Country/Region').max().reset_index()[['Country/Region','Confirmed']]
world
# Out:
#           Country/Region  Confirmed
# 0            Afghanistan         22
# 1                Albania         64
# 2                Algeria         87
# 3                Andorra         53
# 4    Antigua and Barbuda          1
# ..                   ...        ...
# 150              Uruguay         79
# 151           Uzbekistan         23
# 152            Venezuela         42
# 153              Vietnam         85
# 154               Zambia          2
#
# [155 rows x 2 columns]

# %%
patientinfo
# Out:
#       patient_id  global_num     sex  birth_year age country  \
# 0     1000000001         2.0    male      1964.0  50   Korea
# 1     1000000002         5.0    male      1987.0  30   Korea
# 2     1000000003         6.0    male      1964.0  50   Korea
# 3     1000000004         7.0    male      1991.0  20   Korea
# 4     1000000005         9.0  female      1992.0  20   Korea
# ...          ...         ...     ...         ...  ..     ...
# 2213  6100000085         NaN    male      1990.0  30   Korea
# 2214  7000000001       139.0    male      1998.0  20   Korea
# 2215  7000000002       222.0  female      1998.0  20   Korea
# 2216  7000000003      4345.0  female      1972.0  40   Korea
# 2217  7000000004      5534.0    male      1974.0  40   Korea
#
#               province         city disease        infection_case  \
# 0                Seoul   Gangseo-gu     NaN       overseas inflow
# 1                Seoul  Jungnang-gu     NaN       overseas inflow
# ...

# %%
time
# Out:
#           date  time    test  negative  confirmed  released  deceased
# 0   2020-01-20    16       1         0          1         0         0
# 1   2020-01-21    16       1         0          1         0         0
# 2   2020-01-22    16       4         3          1         0         0
# 3   2020-01-23    16      22        21          1         0         0
# 4   2020-01-24    16      27        25          2         0         0
# ..         ...   ...     ...       ...        ...       ...       ...
# 56  2020-03-16     0  274504    251297       8236      1137        75
# 57  2020-03-17     0  286716    261105       8320      1401        81
# 58  2020-03-18     0  295647    270888       8413      1540        84
# 59  2020-03-19     0  307024    282555       8565      1947        91
# 60  2020-03-20     0  316664    292487       8652      2233        94
#
# [61 rows x 7 columns]

# %%
data = pd.DataFrame({'confirmed': time.confirmed,'released': time.released})
f,ax = plt.subplots(figsize = (20,10))
ax.plot_date(x=time.date,y= "confirmed",data=data,label="Confirmed People",linestyle = '-')
ax.plot_date(x=time.date,y= "released",data=data,label="released People",linestyle = '-')
plt.xticks(rotation = 90)
plt.xlabel("DATE")
plt.ylabel("Number of People")
plt.title("CONFIRMED AND RELEASED BY DATE")
plt.legend()
plt.grid()
plt.show()

# %%
patientInfo.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province  \
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by  \
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date  \
# ...

# %%
patientinfo.dropna(subset=['age'],inplace=True)

# %%
patientinfo.age = [i.rsplit('s',1)[0] if 's' in i else i for i in patientinfo.age]

# %%
province_list = list(cases['province'].unique())
number_of_cases = []
for j in province_list:
    x = cases[cases['province'] == j]
    total = sum(x.confirmed)
    number_of_cases.append(total)
ok = pd.DataFrame({'province_list': province_list, 'number_of_cases' : number_of_cases})
ok_index = (ok['number_of_cases'].sort_values(ascending = False)).index.values
ok_data = ok.reindex(ok_index)
province_list.append('others')
number_of_cases.append(296)
data = pd.DataFrame({'province_list': province_list, 'number_of_cases' : number_of_cases})
new_index = (data['number_of_cases'].sort_values(ascending = False)).index.values
sorted_data = data.reindex(new_index)

# %%
ok_data
# Out:
#         province_list  number_of_cases
# 2               Daegu             6066
# 14   Gyeongsangbuk-do             1145
# 0               Seoul              218
# 8         Gyeonggi-do              164
# 11  Chungcheongnam-do              115
# 1               Busan               91
# 15   Gyeongsangnam-do               85
# 7              Sejong               40
# 10  Chungcheongbuk-do               31
# 4             Incheon               30
# 9          Gangwon-do               29
# 6               Ulsan               28
# 5             Daejeon               22
# 3             Gwangju               16
# 12       Jeollabuk-do                7
# 13       Jeollanam-do                4
# 16            Jeju-do                4

# %%
sort = sorted_data[ sorted_data['number_of_cases'] < 90 ].index
# Delete these row indexes from dataFrame
sorted_data.drop(sort, inplace=True)
sorted_data
# Out:
#         province_list  number_of_cases
# 2               Daegu             6066
# 14   Gyeongsangbuk-do             1145
# 17             others              296
# 0               Seoul              218
# 8         Gyeonggi-do              164
# 11  Chungcheongnam-do              115
# 1               Busan               91

# %%
ind = world2[ world2['ID'] < 100].index
# Delete these row indexes from dataFrame
world2.drop(ind, inplace=True)
world2
# Out:
#         country     ID
# 9         China  10446
# 23        Italy    588
# 24        Japan    731
# 41  South Korea    938

# %%
explode = (0.1, 0, 0, 0,0,0,0)
plt.figure(figsize=(15,12), dpi= 80)
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
plt.pie(world2['ID'], labels=world2['country'],autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.show()

# %%
explode = (0.1, 0, 0, 0,0,0,0)
plt.figure(figsize=(15,12), dpi= 80)
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
plt.pie(world['Confirmed'], labels=world['Country/Region'],autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.show()

# %%
def myconverter(obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()

# %%
lat = [37.532600, 35.166668, 35.834236, 37.456257, 35.166668, 36.351002,35.549999, 26.291321, 37.156000, 37.87472, 36.63722, 36.32139,35.82194, 34.99014, 36.56556, 35.22806, 33.499621]
log = [127.024612, 129.066666, 128.534210, 126.705208,126.916664, 127.385002, 129.316666, 127.165604, 127.006000,127.73417, 127.48972, 127.41972, 127.14889, 126.47899, 128.725,128.68111, 126.531188]
lat = [float(np_float) for np_float in lat]
log = [float(np_float) for np_float in log]
val = [218,91,6066,30,16,22,28,40,164,29,31,115,7,4,1145,85,4]
val = [float(np_float) for np_float in val]

# %%
import folium
import math

data1 = pd.DataFrame({
                "latitude":lat,
                "longitude":log, 
                'name':['Seoul', 'Busan', 'Daegu', 'Incheon', 'Gwangju', 'Daejeon','Ulsan', 'Sejong', 'Gyeonggi-do', 'Gangwon-do','Chungcheongbuk-do', 'Chungcheongnam-do', 'Jeollabuk-do','Jeollanam-do', 'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Jeju-do'], 
                'value' :val})

route_map = folium.Map(location=[36.5,128],
                       min_zoom=3,
                       max_zoom=10,
                       zoom_start=6.5,
                       tiles="cartodbpositron")
for i in range(0,len(data1)):
    folium.Circle(
       location=[data1.iloc[i]['latitude'], data1.iloc[i]['longitude']],
       popup=data1.iloc[i]['name'],
       radius=data1.iloc[i]['value']*8,
       color='crimson',
       fill=True,
       fill_color='crimson'
    ).add_to(route_map)

route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
